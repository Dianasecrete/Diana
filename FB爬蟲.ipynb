# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time
import requests
from selenium.common.exceptions import NoSuchElementException
import itertools

# %%
service_args=[]
service_args.append('--load-images=no')
service_args.append('--disk-cache=yes')
service_args.append('--ignore-ssl-errors=true')
driver= webdriver.PhantomJS(r"C:\Users\X555LB\phantomjs-2.1.1-windows\bin\phantomjs.exe",service_args=service_args)

# %%
# driver= webdriver.Firefox()

# driver.get('https://www.facebook.com')
# conbs=bs(driver.page_source)

# time.sleep(2)
# driver.find_element_by_id('email').send_keys("carry4199@gmail.com")
# driver.find_element_by_id('pass').send_keys("001122334455")
# driver.find_element_by_id('loginbutton').click()
driver.get('https://www.facebook.com/862351570448746')

    
driver.find_element_by_link_text('關於').click()
for i in range(10):
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
time.sleep(5)
driver.get(driver.current_url)
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a[0].select('._50f8._50f4'))
driver.get(driver.current_url+'&section=education&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a)
driver.get(driver.current_url+'&section=living&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a)
driver.get(driver.current_url+'&section=contact-info&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a)
driver.get(driver.current_url+'&section=relationship&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a)
driver.get(driver.current_url+'&section=bio&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a)
driver.get(driver.current_url+'&section=year-overviews&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a[0].select('._50f8._50f4'))
# Out:
# C:\Users\X555LB\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\X555LB\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# [<span class="_50f8 _50f4">沒有工作場所可顯示</span>, <span class="_50f8 _50f4">沒有學校可顯示</span>, <span class="_50f8 _50f4">沒有地標可顯示</span>, <span class="_50f8 _50f4">沒有感情狀態資訊可顯示</span>]
# ...

# %%
driver= webdriver.Firefox()

driver.get('https://www.facebook.com')
conbs=bs(driver.page_source)

time.sleep(2)

driver.find_element_by_id('email').send_keys("kevin19961009@gmail.com")
driver.find_element_by_id('pass').send_keys("kkkkk5553705")
driver.find_element_by_id('loginbutton').click()
driver.get('https://www.facebook.com/700800113360704')

    
driver.find_element_by_link_text('關於').click()

for i in range(10):
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(1)
conbs0=bs(driver.page_source)
driver.save_screenshot('screenie.png')
# print(conbs)


# time.sleep(5)
driver.get(driver.current_url)
conbs=bs(driver.page_source)
# print(conbs)
a=conbs.select('._4ms4')
print(a[0].select('._50f5'))
print(a[0].select(".fsm.fwn.fcg"))
print(a[0].select('._h72.lfloat._ohe._50f7'))
driver.get(driver.current_url+'&section=education&pnref=about')
conbs=bs(driver.page_source)

a=conbs.select('._4ms4')
print(a[0].select('._50f5'))
print(a[0].select(".fsm.fwn.fcg"))
print(a[0].select('._h72.lfloat._ohe._50f7'))
driver.get(driver.current_url+'&section=living&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a[0].select('._50f5'))
print(a[0].select(".fsm.fwn.fcg"))
print(a[0].select('._h72.lfloat._ohe._50f7'))
driver.get(driver.current_url+'&section=contact-info&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a[0].select('._50f5'))
print(a[0].select(".fsm.fwn.fcg"))
print(a[0].select('._h72.lfloat._ohe._50f7'))
driver.get(driver.current_url+'&section=relationship&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a[0].select('._50f5'))
print(a[0].select(".fsm.fwn.fcg"))
print(a[0].select('._h72.lfloat._ohe._50f7'))
driver.get(driver.current_url+'&section=bio&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a[0].select('._50f5'))
print(a[0].select(".fsm.fwn.fcg"))
print(a[0].select('._h72.lfloat._ohe._50f7'))
driver.get(driver.current_url+'&section=year-overviews&pnref=about')
conbs=bs(driver.page_source)
a=conbs.select('._4ms4')
print(a[0].select('._50f5'))
print(a[0].select("._2pi4"))
print(a[0].select('._h72.lfloat._ohe._50f7'))
print(a[0].select('._50f4'))
# Out:
# C:\Users\X555LB\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\X555LB\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# []
# ...

# %%
conbs
# Out:
# <html class="" id="facebook" lang="zh-Hant"><head><meta charset="utf-8"/><meta content="origin-when-crossorigin" id="meta_referrer" name="referrer"/><script>window._cstart=+new Date();</script> <script>function envFlush(a){function b(c){for(var d in a)c[d]=a[d];}if(window.requireLazy){window.requireLazy(['Env'],b);}else{window.Env=window.Env||{};b(window.Env);}}envFlush({"ajaxpipe_token":"AXjLS8TrPRecml9r","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"enableOnRequire":false},"shouldLogCounters":true,"timeslice_categories":{"react_render":true,"reflow":true},"khsh":"0`sj`e`rm`s-0fdu^gshdoer-0gc^eurf-3gc^eurf;1;enbtldou;fduDmdldourCxO`ld-2YLMIuuqSdptdru;qsnunuxqd;rdoe-0unjdojnx-0unjdojnx0-0gdubi^rdbsduOdv-0`sj`e`r-0q`xm`r-0StoRbs`qhof-0mhoj^q`xm`r","web_speed_as
# ...

# %%
"照片"

photo=conbs0.select('._53s.fbPhotoCurationControlWrapper.fbPhotoStarGridElement.fbPhotoStarGridNonStarred.focus_target._53s.fbPhotoCurationControlWrapper')
# print(photo)
for img in photo:
    print(img.select('a')[0]['aria-label'])
    print(img.select('i')[0]['style'].replace('(','*').replace(');','*').split('*')[1])
# Out:
# 圖像裡可能有1 人、鞋子和文字
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-0/p206x206/13895397_1732461627026985_4837185319988801044_n.jpg?oh=a733945258b3cfc463a2a2b33d9f4fd6&oe=59C92CD6
# 圖像裡可能有8 個人、鞋子和戶外
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-0/p206x206/13495315_1262196877131304_3997840310303993698_n.jpg?oh=47a3a4963c625caf20f4538b07374884&oe=5A111CBE
# 圖像裡可能有22 個人、微笑的人、大家站著和文字
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-0/p206x206/13244843_515627198621242_5306232214949073710_n.jpg?oh=e47574d8c02567023eb030afd442d581&oe=59CF0801
# 圖像裡可能有12 個人、微笑的人
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-0/p206x206/10432108_809937779116205_469483470996824114_n.jpg?oh=49b488710f6c3c376f190fc4f11d4dc2&oe=59D586D2
# 圖像裡可能有2 個人、微笑的人
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-0/p206x206/1919088_891048601002520_2138821739603443021_n.jpg?oh=d5f772ea55c5b8bdcdd63eff9fe6951e&oe=5A11187E
# 圖像裡可能有3 個人、室內
# ...

# %%
title=conbs0.select('._30f')

title
for titles in title:
    if len(titles.select('._51sx')):
        print(titles.select('._51sx')[0].text)
        print('-------------------------')
        for content in titles.select('._5rz'):
            print(content.text)
        print('-------------------------')
# Out:
# 關於
# -------------------------
# -------------------------
# 朋友
# -------------------------
# -------------------------
# 相片
# -------------------------
# -------------------------
# 打卡動態
# -------------------------
# 東吳大學
# 回報東吳舞研oncelove
# Jack Pan Cafe 傑克潘餐館
# 東吳大學
# 劍湖山王子大飯店 Janfusun Prince Hotel
# 劍湖山摩天輪最高點
# 回報劍湖山世界
# 台中宫原眼科
# -------------------------
# 運動
# -------------------------
# 東吳會計系女籃
# -------------------------
# 音樂
# -------------------------
# 蘋果烏克麗麗家族樂手／樂團
# Vierze樂手／樂團
# Gyniuz X Phebe樂手／樂團
# Bii 畢書盡樂手／樂團
# 琴時鳴樂古風音樂創作團體樂手／樂團
# 曾沛慈 Pets Tseng樂手／樂團
# 陶大曄樂手／樂團
# 超世代二胡玩家劉思捷樂手／樂團
# -------------------------
# 電影
# -------------------------
# 六弄咖啡館 At Cafe 6電影
# -------------------------
# 電視節目
# -------------------------
# 犯罪心理大約 3 年前
# -------------------------
# 應用程式和遊戲
# -------------------------
# 神奇寶貝系列 Pokémon遊戲／玩具
# -------------------------
# 說讚的內容
# -------------------------
# Pocket Money 口袋財經網站讚追蹤追蹤中
# 3Q青少年領袖成長營教育讚追蹤追蹤中
# 2017北市大學材系畢業展：同步率社群讚追蹤追蹤中
# ...

# %%
import json
from pprint import pprint

with open('users.json',encoding='utf8') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-244-ebb87c05eafc> in <module>()
#       3
#       4 with open('users.json',encoding='utf8') as data_file:
# ----> 5     data = json.load(data_file)
#       6
#       7 pprint(data)
#
# C:\Users\X555LB\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# C:\Users\X555LB\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
# ...
